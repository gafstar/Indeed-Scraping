# %%
import requests
import bs4
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import time

# %%
url='https://www.indeed.com/jobs?q=data+scientist+%24120000&l=Sunnyvale%2C+CA'

# %%
#making a list of cities to run through
cities = ['Redwood+City', 'Menlo+Park', 'San+Jose', 'Milpitas', 'Sunnyvale', 'Santa+Clara']

# %%
### Rithika suggested I merge all of the find_alls into one large function, so the code below was created with her assistance. 

def parse(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser', from_encoding="utf-8")
    df = pd.DataFrame(columns=["Title","Location","Company","Salary", "Synopsis"])
    for each in soup.find_all(class_= "result" ):
        try: 
            title = each.find(class_='jobtitle').text.replace('\n', '')
        except:
            title = 'None'
        try:
            location = each.find('span', {'class':"location" }).text.replace('\n', '')
        except:
            location = 'None'
        try: 
            company = each.find(class_='company').text.replace('\n', '')
        except:
            company = 'None'
        try:
            salary = each.find('span', {'class':'no-wrap'}).text.text.replace('\n', '')
        except:
            salary = 'None'
        synopsis = each.find('span', {'class':'summary'}).text.replace('\n', '')
        df = df.append({'Title':title, 'Location':location, 'Company':company, 'Salary':salary, 'Synopsis':synopsis}, ignore_index=True)
    return df

# %%
parse(url)
# Out:
#                                                 Title               Location  \
# 0                          Principal Data Scientist I                   None
# 1                               Senior Data Scientist                   None
# 2   Software (Big Data) Engineer - 5 Years Experience                   None
# 3                           Principal Scientist, DMPK                   None
# 4                           Data Scientist (GEC11901)    Sunnyvale, CA 94087
# 5                           Data Scientist (GEC11901)    Sunnyvale, CA 94087
# 6                                        Data Analyst  Santa Clara, CA 95051
# 7                   Data Scientist - New College Grad    Sunnyvale, CA 94089
# 8                      Data Scientist – Deep Learning    Sunnyvale, CA 94085
# 9                                      Data Scientist          Sunnyvale, CA
# 10                                     Data Scientist        Santa Clara, CA
# 11                                     Data Scientist          Sunnyvale, CA
# 12                                     Data Scientist  Santa Clara, CA 95054
# 13                                     Data Scientist        Santa Clara, CA
# 14                                     Data Scientist                   None
# 15       Data Engineer - BI, Python, Data Warehousing                   None
#
#                                      Company Salary  \
# 0                                      Roche   None
# 1                                     Akamai   None
# 2                Fast Growing Financial Firm   None
# 3           Pharmacyclics, an Abbvie Company   None
# 4                             Walmart Stores   None
# 5                          Walmart eCommerce   None
# 6                                    Creatus   None
# 7                                 Proofpoint   None
# 8                                Bosch Group   None
# 9                                  Microsoft   None
# 10                   Optima Global Solutions   None
# 11                                     Huobi   None
# 12                       Abbott Laboratories   None
# 13                        Palo Alto Networks   None
# 14                                  CloudCar   None
# 15                                    eXcell   None
#
#                                              Synopsis
# 0                               Principal Data Sci...
# 1                               As a Senior Data S...
# 2                               The Data Engineer ...
# 3                               Review nonclinical...
# 4               The @WalmartLabs Personalization t...
# 5               The @WalmartLabs Personalization t...
# 6               Experience with Data Warehousing a...
# 7               Proficiency in data exploration te...
# 8               Take responsibility for preparing ...
# 9   Data mining, machine learning, information ret...
# 10              Working experience in end to end d...
# 11              Build data pipelines that import t...
# 12              Able to train and develop junior d...
# 13              Collaborate with data engineers to...
# 14                              Looking for someon...
# 15                              Collaboration with...

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 200 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.
i = 0
results = []
df_more = pd.DataFrame(columns=["Title","Location","Company","Salary", "Synopsis"])
for city in cities:
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        url = url_template.format(city, start)
        # Append to the full set of results
        html = requests.get(url)
        soup = BeautifulSoup(html.content, 'html.parser', from_encoding="utf-8")
        for each in soup.find_all(class_= "result" ):
            try: 
                title = each.find(class_='jobtitle').text.replace('\n', '')
            except:
                title = None
            try:
                location = each.find('span', {'class':"location" }).text.replace('\n', '')
            except:
                location = None
            try: 
                company = each.find(class_='company').text.replace('\n', '')
            except:
                company = None
            try:
                salary = each.find('span', {'class':'no-wrap'}).text.replace('\n', '')
            except:
                salary = None
            try:
                synopsis = each.find('span', {'class':'summary'}).text.replace('\n', '')
            except:
                synopsis = None
            df_more = df_more.append({'Title':title, 'Location':location, 'Company':company, 'Salary':salary, 'Synopsis':synopsis}, ignore_index=True)
            i += 1
            if i % 1000 == 0:  # Ram helped me build this counter to see how many. You can visibly see Ram's vernacular in the print statements.
                print('You have ' + str(i) + ' results. ' + str(df_more.dropna().drop_duplicates().shape[0]) + " of these aren't rubbish.")
# Out:
# You have 1000 results. 38 of these aren't rubbish.

# %%
df_more.to_csv('Indeed_jobs_near_me.csv', encoding='utf-8')

# %%
df_more = pd.read_csv('C:/Users/Ghezae/Indeed_jobs_near_me.csv')

# %%
df_more.drop('Unnamed: 0', axis =1, inplace=True)

# %%
df_more.head()
# Out:
#                                           Title Location  \
# 0       Commercial, Marketing Operations Intern      NaN
# 1                        DMPK (DM Focus) Intern      NaN
# 2  Data Engineer - BI, Python, Data Warehousing      NaN
# 3                    Data Scientist - Insurance      NaN
# 4                            Scientist, XRD/XRR      NaN
#
#                                     Company  \
# 0          Pharmacyclics, an Abbvie Company
# 1          Pharmacyclics, an Abbvie Company
# 2                                    eXcell
# 3                                  Blue Owl
# 4                                  EAG Inc.
#
#                                        Salary  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                  $200,000 - $350,000 a year
# 4                                         NaN
#
#                                             Synopsis
# 0                              Collect quantitati...
# 1                              Good documentation...
# 2                              Collaboration with...
# 3                              This role will req...
# 4                              Able to communicat...

# %%
print(df_more[df_more.Salary != 'None'].shape)
# Out:
# (1896, 5)

# %%
df_more = df_more[df_more.Salary !='None'].drop_duplicates().dropna()

# %%
df_more.head()
# Out:
#                                 Title  \
# 12                     Data Scientist
# 32       Principle NLP Data Scientist
# 50   Data Scientist - Recommendations
# 51  Summer 2019 Intern - Data Science
# 53                     Data Scientist
#
#                                              Location               Company  \
# 12                                    Santa Clara, CA             vysystems
# 32                         San Francisco Bay Area, CA          R2 Global AI
# 50                                  San Francisco, CA            Stitch Fix
# 51  San Francisco, CA 94105 (Financial District area)            Salesforce
# 53                                  San Francisco, CA                 Chime
#
#                                                Salary  \
# 12                                  $50 - $60 an hour
# 32                         $200,000 - $250,000 a year
# 50                  $108,000 - $159,000 a year (In...
# 51                  $97,000 - $143,000 a year (Ind...
# 53                  $122,000 - $180,000 a year (In...
#
#                                              Synopsis
# 12  Data Scientist with experience in ML/Stats & D...
# 32              Principal NLP Data Scientist. The ...
# 50              Work in a strong, collaborative en...
# 51              Summer 2019 Intern - Data Science....
# 53              And intermediate knowledge of SQL ...
